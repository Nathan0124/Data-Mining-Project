# %%
import numpy as np, scipy as sp,pandas as pd, matplotlib.pyplot as plt
import matplotlib, sklearn
import os,sys,csv

# %% [markdown]
# ## Data IO

# %%
trainPath= '../data/train.csv'
testPath= '../test.csv'

# %%
def csv_nrows(fpath):
    count = 0
    with open(fpath, "r") as csvfile:
        reader = csv.reader(csvfile)
        reader.next()
        '''
        for line in reader:
            count += 1
        '''
        count = sum(1 for row in reader)
    return count

# %%
def csv_split(fpath, nrows=5000000):
    count = csv_nrows(fpath)
    fname, ext = os.path.splitext(fpath)
    with open(fpath, "r") as csvfile:
        reader = csv.reader(csvfile)
        header = reader.next()
        
        count = 0
        for line in reader:
            if count% nrows == 0:
                print "New Patch", int(count//nrows)
                dpath = fname + '_' + str(count//nrows) + ext
                writer = csv.writer(open(dpath, 'wb'))
                writer.writerow(header)
            writer.writerow(line)
            count += 1


    print count
    print 'Done'

# %%
csv_split(trainPath)

# %%
print csv_nrows(trainPath)

# %%
train_data = pd.read_csv(trainPath)
test_data = pd.read_csv(testPath)

# %% [markdown]
# ## Feature Processing

# %%
headers = ['date_time', 
           'site_name',
           'posa_continent',
           'user_location_country',
           'user_location_region',
           'user_location_city',
           'orig_destination_distance',
           'user_id',
           'is_mobile',
           'is_package',
           'channel',
           'srch_ci',
           'srch_co',
           'srch_adults_cnt',
           'srch_children_cnt',
           'srch_rm_cnt',
           'srch_destination_id',
           'srch_destination_type_id',
           'hotel_continent',
           'hotel_country',
           'hotel_market',
           'is_booking',
           'cnt',
           'hotel_cluster']

new_fields = ['in_days', 'in_date']
modified = ['date_time']

updated = ['date_time',
           'in_date',
           'in_days',
           'site_name',
           'posa_continent',
           'user_location_country',
           'user_location_region',
           'user_location_city',
           'hotel_continent',
           'hotel_country',
           'hotel_market',
           'srch_destination_id',
           'orig_destination_distance',
           'user_id',
           'is_mobile',
           'is_package',
           'channel',
           'srch_adults_cnt',
           'srch_children_cnt',
           'srch_rm_cnt',
           'srch_destination_type_id',
           'is_booking',
           'cnt',
           'hotel_cluster']

# %%
sample = pd.read_csv('../data/train_0.csv')

# %%
def time_feature_processing(df):
    def time_interval(row):
        if pd.isnull(row['srch_ci']) or pd.isnull(row['srch_co']):
            return 1
        st = pd.Period(row['srch_ci'],freq='D')
        et = pd.Period(row['srch_co'],freq='D') 
        return et-st
    
    def time_midpoint(row):
        if pd.isnull(row['srch_ci']) or pd.isnull(row['srch_co']):
            return 0
        st = pd.Period(row['srch_ci'],freq='D')
        et = pd.Period(row['srch_co'],freq='D') 

        date = st + (et - st) / 2
        return  date.dayofyear - 1
    
    def time_dayofyear(row):
        if pd.isnull(row['date_time']):
            return 0
        tstamp = pd.to_datetime(row['date_time'])
        #print tstamp
        return tstamp.dayofyear - 1 + tstamp.hour / 24.
    
    
    df['in_days'] = df.apply(time_interval, axis= 1)
    df['in_date'] = df.apply(time_midpoint, axis= 1)
    df['date_time'] = df.apply(time_dayofyear, axis = 1)
    df.drop('srch_ci', axis=1, inplace=True)
    df.drop('srch_co', axis=1, inplace=True)

# %%
def nan_feature_processing(df, colname):
    med = df[colname].median()
    df[colname] = df[colname].fillna(med)

# %%
part_df = sample[:50000]
time_feature_processing(part_df)
nan_feature_processing(part_df,'orig_destination_distance')
#part_df[updated]
# Out:
# /home/nianzu/miniconda2/envs/work/lib/python2.7/site-packages/ipykernel/__main__.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nianzu/miniconda2/envs/work/lib/python2.7/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nianzu/miniconda2/envs/work/lib/python2.7/site-packages/ipykernel/__main__.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nianzu/miniconda2/envs/work/lib/python2.7/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nianzu/miniconda2/envs/work/lib/python2.7/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nianzu/miniconda2/envs/work/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#         date_time  site_name  posa_continent  user_location_country  \
# 0      222.291667          2               3                     66
# 1      222.333333          2               3                     66
# 2      222.333333          2               3                     66
# 3      220.750000          2               3                     66
# 4      220.750000          2               3                     66
# 5      220.750000          2               3                     66
# 6      196.375000          2               3                     66
# 7      196.375000          2               3                     66
# 8      196.375000          2               3                     66
# 9      196.375000          2               3                     66
# 10     196.416667          2               3                     66
# 11     196.416667          2               3                     66
# 12      16.250000          2               3                     66
# 13      17.583333          2               3                     66
# 14      20.250000          2               3                     66
# 15      20.250000          2               3                     66
# 16      21.250000          2               3                     66
# 17      23.458333          2               3                     66
# 18      23.708333          2               3                     66
# 19      57.708333          2               3                     66
# 20      57.750000          2               3                     66
# 21     363.375000          2               3                     66
# 22     363.375000          2               3                     66
# 23     363.375000          2               3                     66
# 24     294.500000          2               3                     66
# 25     313.500000          2               3                     66
# 26     165.625000         30               4                    195
# 27     165.625000         30               4                    195
# 28     325.583333         30               4                    195
# 29     325.583333         30               4                    195
# ...           ...        ...             ...                    ...
# 49970  312.583333          2               3                     66
# 49971  312.583333          2               3                     66
# 49972  159.875000          2               3                     66
# 49973  159.875000          2               3                     66
# 49974  289.833333          2               3                     66
# 49975  289.833333          2               3                     66
# 49976  289.833333          2               3                     66
# 49977  309.833333          2               3                     66
# 49978  309.833333          2               3                     66
# 49979  309.833333          2               3                     66
# 49980  353.833333          2               3                     66
# 49981   52.708333          2               3                     66
# 49982   52.708333          2               3                     66
# 49983   52.708333          2               3                     66
# 49984   52.708333          2               3                     66
# 49985   52.708333          2               3                     66
# 49986   52.708333          2               3                     66
# 49987   52.708333          2               3                     66
# 49988   57.625000          2               3                     66
# 49989   57.625000          2               3                     66
# 49990   57.625000          2               3                     66
# 49991   57.666667          2               3                     66
# 49992   66.666667          2               3                     66
# 49993   66.666667          2               3                     66
# 49994   83.708333          2               3                     66
# 49995  237.416667          2               3                     66
# 49996  237.541667          2               3                     66
# 49997  237.541667          2               3                     66
# 49998  237.541667          2               3                     66
# 49999  237.541667          2               3                     66
#
#        user_location_region  user_location_city  orig_destination_distance  \
# 0                       348               48862                 2234.26410
# 1                       348               48862                 2234.26410
# 2                       348               48862                 2234.26410
# 3                       442               35390                  913.19320
# 4                       442               35390                  913.62590
# 5                       442               35390                  911.51420
# 6                       189               10067                 1105.37005
# 7                       189               10067                 1105.37005
# 8                       189               10067                 1105.37005
# 9                       189               10067                 1105.37005
# 10                      189               10067                 1105.37005
# 11                      189               10067                 1105.37005
# 12                      318               22418                  420.66420
# 13                      318               52078                 1105.37005
# 14                      318               22418                  421.85510
# 15                      318               22418                  421.85510
# 16                      318               22418                  421.85510
# 17                      318               22418                  421.85510
# 18                      318               52078                 1105.37005
# 19                      318               52078                 1105.37005
# 20                      318               52078                 1105.37005
# 21                      318               21655                 1105.37005
# 22                      318               21655                 1105.37005
# 23                      318               21655                 1105.37005
# 24                      318               52997                   47.70270
# 25                      318               48382                 1753.26170
# 26                      548               56440                 1105.37005
# 27                      548               56440                 1105.37005
# 28                      991               47725                 1105.37005
# 29                      991               47725                 1105.37005
# ...                     ...                 ...                        ...
# 49970                   447               50736                   24.16060
# 49971                   447               50736                   24.16060
# 49972                   447               50736                  572.95490
# 49973                   447               50736                  572.95490
# 49974                   447               33335                   22.03380
# 49975                   447               33335                   22.03380
# 49976                   447               33335                   22.03380
# 49977                   447               33335                    7.41230
# 49978                   447               33335                    7.40520
# 49979                   447               33335                    7.40520
# 49980                   447                 902                  583.65150
# 49981                   174               30055                 2257.79600
# 49982                   174               30055                 2259.39590
# 49983                   174               30055                 2258.48650
# 49984                   174               30055                 2259.03740
# 49985                   174               30055                 2255.83240
# 49986                   174               30055                 2257.82990
# 49987                   174               30055                 2258.17380
# 49988                   174               30055                 2253.96840
# 49989                   174               30055                 2259.54280
# 49990                   174               30055                 2254.67900
# 49991                   174               30055                 2258.10790
# 49992                   174               30055                 2255.13840
# 49993                   174               30055                 2250.06500
# 49994                   174               30055                 6228.16320
# 49995                   174               30055                  261.20320
# 49996                   174               30055                 1745.86770
# 49997                   174               30055                 1745.33980
# 49998                   174               30055                 1745.91950
# 49999                   174               30055                 1745.91950
#
#        user_id  is_mobile  is_package   ...     srch_destination_id  \
# 0           12          0           1   ...                    8250
# 1           12          0           1   ...                    8250
# 2           12          0           0   ...                    8250
# 3           93          0           0   ...                   14984
# 4           93          0           0   ...                   14984
# 5           93          0           0   ...                   14984
# 6          501          0           0   ...                    8267
# 7          501          0           1   ...                    8267
# 8          501          0           0   ...                    8267
# 9          501          0           0   ...                    8267
# 10         501          0           0   ...                    8267
# 11         501          0           0   ...                    8267
# 12         756          0           1   ...                    8291
# 13         756          0           1   ...                    8291
# 14         756          0           1   ...                    8291
# 15         756          0           1   ...                    8291
# 16         756          0           1   ...                    8291
# 17         756          0           1   ...                    8291
# 18         756          0           1   ...                    8291
# 19         756          0           1   ...                    8291
# 20         756          0           1   ...                    8291
# 21         756          0           1   ...                   12193
# 22         756          0           1   ...                   12193
# 23         756          0           1   ...                   12193
# 24         776          0           0   ...                   27082
# 25         776          0           1   ...                    8250
# 26        1048          0           1   ...                    1385
# 27        1048          0           1   ...                    1385
# 28        1048          0           0   ...                    8803
# 29        1048          0           0   ...                    8803
# ...        ...        ...         ...   ...                     ...
# 49970   181701          0           0   ...                   11625
# 49971   181701          0           0   ...                   11625
# 49972   181701          0           0   ...                   12175
# 49973   181701          0           0   ...                   12175
# 49974   181701          0           0   ...                   11625
# 49975   181701          0           0   ...                   11625
# 49976   181701          0           0   ...                   11625
# 49977   181701          0           0   ...                   12843
# 49978   181701          0           0   ...                   12843
# 49979   181701          0           0   ...                   12843
# 49980   181701          0           0   ...                   12175
# 49981   181983          0           1   ...                    8791
# 49982   181983          0           1   ...                    8791
# 49983   181983          0           1   ...                    8791
# 49984   181983          0           1   ...                    8791
# 49985   181983          0           1   ...                    8791
# 49986   181983          0           1   ...                    8791
# 49987   181983          0           1   ...                    8791
# 49988   181983          0           1   ...                    8791
# 49989   181983          0           1   ...                    8791
# 49990   181983          0           1   ...                    8791
# 49991   181983          0           1   ...                    8791
# 49992   181983          0           1   ...                    8791
# 49993   181983          0           1   ...                    8791
# 49994   181983          0           1   ...                    8746
# 49995   181983          0           1   ...                    8250
# 49996   181983          0           1   ...                    8230
# 49997   181983          0           1   ...                    8230
# 49998   181983          0           1   ...                    8230
# 49999   181983          0           1   ...                    8230
#
#        srch_destination_type_id  is_booking  cnt  hotel_continent  \
# 0                             1           0    3                2
# 1                             1           1    1                2
# 2                             1           0    1                2
# 3                             1           0    1                2
# 4                             1           0    1                2
# 5                             1           0    1                2
# 6                             1           0    2                2
# 7                             1           0    1                2
# 8                             1           0    1                2
# 9                             1           0    1                2
# 10                            1           0    1                2
# 11                            1           0    1                2
# 12                            1           0    5                2
# 13                            1           0    1                2
# 14                            1           0    1                2
# 15                            1           0    1                2
# 16                            1           0    1                2
# 17                            1           0    1                2
# 18                            1           0    1                2
# 19                            1           0    1                2
# 20                            1           1    1                2
# 21                            6           0    2                2
# 22                            6           0    2                2
# 23                            6           0    1                2
# 24                            6           0    2                2
# 25                            1           0    1                2
# 26                            1           0    1                0
# 27                            1           1    1                0
# 28                            1           0    1                3
# 29                            1           0    1                3
# ...                         ...         ...  ...              ...
# 49970                         1           1    1                2
# 49971                         1           0    2                2
# 49972                         6           0    1                2
# 49973                         6           1    1                2
# 49974                         1           0    3                2
# 49975                         1           0    1                2
# 49976                         1           1    1                2
# 49977                         5           0    2                2
# 49978                         5           0    1                2
# 49979                         5           1    1                2
# 49980                         6           0    2                2
# 49981                         1           0    1                4
# 49982                         1           0    1                4
# 49983                         1           0    1                4
# 49984                         1           0    1                4
# 49985                         1           0    1                4
# 49986                         1           0    1                4
# 49987                         1           0    1                4
# 49988                         1           0    1                4
# 49989                         1           0    1                4
# 49990                         1           0    1                4
# 49991                         1           0    1                4
# 49992                         1           0    1                4
# 49993                         1           0    3                4
# 49994                         1           0    2                6
# 49995                         1           0    1                2
# 49996                         1           0    1                2
# 49997                         1           0    1                2
# 49998                         1           0    1                2
# 49999                         1           0    1                2
#
#        hotel_country  hotel_market  hotel_cluster  in_days  in_date
# 0                 50           628              1        4      240
# 1                 50           628              1        4      242
# 2                 50           628              1        4      242
# 3                 50          1457             80        5      328
# 4                 50          1457             21        5      328
# 5                 50          1457             92        5      328
# 6                 50           675             41        1      212
# 7                 50           675             41        1      212
# 8                 50           675             69        1      212
# 9                 50           675             70        1      212
# 10                50           675             98        1      212
# 11                50           675             10        1      212
# 12                50           191             18        3      107
# 13                50           191             28        3      106
# 14                50           191             25        3      107
# 15                50           191             25        2      108
# 16                50           191             25        2      108
# 17                50           191             25        2      107
# 18                50           191             25        2      107
# 19                50           191              2        2      107
# 20                50           191              2        2      108
# 21                50           406             16        2       37
# 22                50           406             16        2       37
# 23                50           406             94        2       37
# 24                50           641             77        1      297
# 25                50           628             24        2       22
# 26               185           185             58        8      253
# 27               185           185             58        8      252
# 28               151            69             36        2      177
# 29               151            69             82        2      177
# ...              ...           ...            ...      ...      ...
# 49970             50           658             15        1      331
# 49971             50           658             15        1      331
# 49972             50           366             10        3      282
# 49973             50           366             10        3      282
# 49974             50           658             25        1      330
# 49975             50           658             25        1      330
# 49976             50           658             25        1      330
# 49977             50           661              9        1      324
# 49978             50           661              9        1      324
# 49979             50           661              9        1      324
# 49980             50           366             17        4       15
# 49981              8           110             89        4      102
# 49982              8           110             52        4      102
# 49983              8           110             65        4      102
# 49984              8           110             87        4      102
# 49985              8           110             65        4      102
# 49986              8           110             66        4      102
# 49987              8           110             52        4      102
# 49988              8           110             69        4       88
# 49989              8           110              0        4       88
# 49990              8           110             65        4       88
# 49991              8           110             84        6       90
# 49992              8           110             52        7       89
# 49993              8           110             66        7       89
# 49994            105            29             95        4      277
# 49995             50           628             24        2      256
# 49996             50           637             98        4      255
# 49997             50           637             41        4      255
# 49998             50           637             95        4      255
# 49999             50           637             95        3      255
#
# [50000 rows x 24 columns]

# %% [markdown]
# ## Feature Analysis

# %%
corr_mat = part_df[updated].corr()
plt.matshow(corr_mat)
plt.colorbar(shrink=0.5)
plt.xticks(np.arange(len(updated)),updated, rotation='vertical')
plt.yticks(np.arange(len(updated)),updated)
plt.show()

# %% [markdown]
# ## Model

# %% [markdown]
# ### Random Forest

# %%
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.cross_validation import cross_val_score

import ml_metrics as mtr

# %%
X = part_df[updated[:-1]].as_matrix()
y = part_df.hotel_cluster.as_matrix()

# %%
def map_5_scorer(estimator, X, y):
    prob = estimator.predict_proba(X)
    def top5(row):
        return sorted(range(len(row)), key=lambda k: row[k], reverse=True)
    
    y = map(lambda x:[x], y)
    y_pred = np.apply_along_axis(top5, axis=1, arr=prob)
    return mtr.mapk(y, y_pred, 5)

# %%
estimator = Pipeline([("imputer", Imputer(missing_values=0,
                                          strategy="median",
                                          axis=0)),
                      ("forest", RandomForestClassifier(n_estimators=100,
                                                       n_jobs=3))])
score = cross_val_score(estimator, X, y, cv=5, scoring=map_5_scorer)
#print("Score = %.2f" % score)
print score, score.mean()
# Out:
# [ 0.10863878  0.12814641  0.12893877  0.11875814  0.09231426] 0.115359272599
